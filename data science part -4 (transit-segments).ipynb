# %% [markdown]
# # master dates

# %%
import pandas as pd 
df=pd.read_csv('transit-segments.csv')
df.head()
# Out:
#    mmsi               name  transit  segment  seg_length  avg_sog  min_sog  \
# 0     1        Us Govt Ves        1        1         5.1     13.2      9.2
# 1     1  Dredge Capt Frank        1        1        13.5     18.6     10.4
# 2     1      Us Gov Vessel        1        1         4.3     16.2     10.3
# 3     1      Us Gov Vessel        2        1         9.2     15.4     14.5
# 4     1  Dredge Capt Frank        2        1         9.2     15.4     14.6
#
#    max_sog  pdgt10        st_time       end_time
# 0     14.5    96.5  2/10/09 16:03  2/10/09 16:27
# 1     20.6   100.0   4/6/09 14:31   4/6/09 15:20
# 2     20.5   100.0   4/6/09 14:36   4/6/09 14:55
# 3     16.1   100.0  4/10/09 17:58  4/10/09 18:34
# 4     16.2   100.0  4/10/09 17:59  4/10/09 18:35

# %%
df.dtypes
# Out:
# mmsi            int64
# name           object
# transit         int64
# segment         int64
# seg_length    float64
# avg_sog       float64
# min_sog       float64
# max_sog       float64
# pdgt10        float64
# st_time        object
# end_time       object
# dtype: object

# %% [markdown]
# # there are two ways to convert the date type into datetime64[ns]
# # one way using parse_dates=['column name']
# # and another by  pd.to_datetime(column_name)

# %%
df2=pd.read_csv('transit-segments.csv',parse_dates=['st_time'])   #some times 1st method won't  work then use 2nd

# %%
df.dtypes
# Out:
# mmsi            int64
# name           object
# transit         int64
# segment         int64
# seg_length    float64
# avg_sog       float64
# min_sog       float64
# max_sog       float64
# pdgt10        float64
# st_time        object
# end_time       object
# dtype: object

# %%
df2.end_time=pd.to_datetime(df2.end_time)

# %%
df2.head()
df2.dtypes
# Out:
# mmsi                   int64
# name                  object
# transit                int64
# segment                int64
# seg_length           float64
# avg_sog              float64
# min_sog              float64
# max_sog              float64
# pdgt10               float64
# st_time       datetime64[ns]
# end_time      datetime64[ns]
# dtype: object

# %%
df[df['min_sog'].between(38,70)]
# Out:
#              mmsi             name  transit  segment  seg_length  avg_sog  \
# 137003  366999708  Uscgc Sea Horse        5        1         1.5     46.6
#
#         min_sog  max_sog  pdgt10         st_time        end_time
# 137003     43.0     49.0   100.0  11/22/08 12:32  11/22/08 12:50

# %%
df[df['st_time'].between('2/10/09','3/01/12')]
# Out:
#              mmsi         name  transit  segment  seg_length  avg_sog  \
# 0               1  Us Govt Ves        1        1         5.1     13.2
# 78           3011   Charleston       16        1        18.9      0.3
# 79           3011   Charleston       17        1        19.2      0.3
# 80           3011   Charleston       18        1        24.7      0.3
# 81           3011   Charleston       19        1        40.1      0.4
# ...           ...          ...      ...      ...         ...      ...
# 262472  967191190   Pathfinder       73        1        21.1      6.3
# 262473  967191190   Pathfinder       74        1        25.7      7.2
# 262474  967191190   Pathfinder       75        1         2.2      8.9
# 262475  967191190   Pathfinder       75        2        26.2      8.7
# 262476  967191190   Pathfinder       76        1        20.2      9.1
#
#         min_sog  max_sog  pdgt10        st_time       end_time
# 0           9.2     14.5    96.5  2/10/09 16:03  2/10/09 16:27
# ...

# %% [markdown]
# # dealing with dublicates

# %%
df3=df2
df3.drop_duplicates(subset=['name'],keep=False)  # all duplicate name get drop
# Out:
#              mmsi              name  transit  segment  seg_length  avg_sog  \
# 0               1       Us Govt Ves        1        1         5.1     13.2
# 7               1        S.d. Gumel        1        1        13.7      6.9
# 34             74            Mcfaul        1        2         1.4     12.8
# 35             74        Sarah Bell        1        1         7.4     12.1
# 84           4731              4731        1        1         2.1     17.7
# ...           ...               ...      ...      ...         ...      ...
# 261975  710482000  Almirante Saboia        1        1         2.0      8.8
# 261980  720768000     Rusty Pelican        1        1        25.2      5.7
# 262051  730000161    Arc. Cartagena        1        1        19.6      3.6
# 262151  857632392          Ct Pilot        1        1         4.6     14.0
# 262396  888888888        Earl Jones        1        1         9.0      5.1
#
# ...

# %%
df2['name'].unique()
# Out:
# array(['Us Govt Ves', 'Dredge Capt Frank', 'Us Gov Vessel', ...,
#        'Ct Pilot', 'Earl Jones', 'Oi'], dtype=object)

# %%
df2['segment'].nunique()
# Out:
# 88

# %%
df2['segment'].max()
# Out:
# 245
